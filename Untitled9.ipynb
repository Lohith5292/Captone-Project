# %%
from tensorflow.keras.models import load_model

# %%
import cv2
cap = cv2.VideoCapture("C://Users//Lohith//Downloads//Made-with-Clipchamp-1.mp4")
no_of_frame = int(cap.get(7))
print(no_of_frame)
# Out:
# 121

# %%
from datetime import datetime
start_time = datetime.now()
import numpy as np
import cv2
temp = []
    
i = 0
while i < no_of_frame:
    ret,frame = cap.read()
    try:
        frame = cv2.resize(frame,(224,224))
    except:
        break
    img = np.asarray(frame)
    img = np.expand_dims(img,axis=0)
    saved_model = load_model("C:/Users/Lohith/vgg1.h5")
    output = saved_model.predict(img)
    val = sum(output[0])
    if val < 0.95:
        temp.append('Non-Pitch')
    else:
        temp.append('Pitch')
    print(str(round((i)/(no_of_frame)*100,2))+'% completed!')
    i+=1

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 8>()
#       5 temp = []
#       7 i = 0
# ----> 8 while i < no_of_frame:
#       9     ret,frame = cap.read()
#      10     try:
#
# NameError: name 'no_of_frame' is not defined

# %%
print(temp)
print(len(temp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 print(temp)
#       2 print(len(temp))
#
# NameError: name 'temp' is not defined

# %%
import pickle
with open('cric_shots.pkl', 'rb') as f:
    model = pickle.load(f)

import pandas as pd
import numpy as np
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions"
cap = cv2.VideoCapture("C://Users//Lohith//Downloads//Made-with-Clipchamp-1.mp4")
noframes=cap.get(7)
print(noframes)
# Initiate holistic model
width = int(cap.get(3))
height = int(cap.get(4))
print(width)
print(height)
shotplayed=[]
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        try:
            image = cv2.cvtColor(frame[int(0.1*height):int(0.7*height)], cv2.COLOR_BGR2RGB)
            #image=cv2.flip(image,1)
            image1=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        except:
            break
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        #image=cv2.flip(image,1)
        
        
        
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
    
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            '''face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())'''
            
            # Concate rows
            row = pose_row
            
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class,body_language_prob)
    
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            shotplayed.append(body_language_class)
        except:
            shotplayed.append("None")
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
print(len(shotplayed))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 import pickle
# ----> 2 with open('cric_shots.pkl', 'rb') as f:
#       3     model = pickle.load(f)
#       5 import pandas as pd
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cric_shots.pkl'

# %%
shotplayed=['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Cover Drive', 'Pull Shot', 'Cover Drive', 'Pull Shot', 'Pull Shot', 'Cover Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Cut Shot', 'straight drive', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'straight drive', 'straight drive', 'straight drive', 'straight drive', 'straight drive', 'straight drive', 'Cut Shot', 'straight drive', 'straight drive', 'straight drive', 'straight drive', 'straight drive', 'straight drive', 'straight drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'straight drive', 'None', 'None', 'None', 'None', 'straight drive', 'None', 'straight drive', 'straight drive', 'straight drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Lofted Shot', 'None', 'None', 'None']
print(shotplayed)
# Out:
# ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'N
# ...

# %%
shotplayed=['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Pull Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Pull Shot', 'Pull Shot', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Cover Drive', 'Pull Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'None', 'None', 'None', 'None', 'None', 'None']
print(len(shotplayed))
# Out:
# 120

# %%
import collections
p=[]
shot=""
for i in range(len(shotplayed)-1):
    if temp[i]=="Pitch" and temp[i+1]=="Pitch":
        if shotplayed[i]!="None":
            p.append(shotplayed[i])
    if temp[i]=="Pitch" and temp[i+1]=="Non-Pitch":
        if shotplayed[i]!="None":
            p.append(shotplayed[i])
        c=collections.Counter(p)
        print(c)
        if len(c)!=0:
            mval=max(list(c.values()))
            for j in c:
                if c[j]==mval:
                    shot=j
    if temp[i]=="Non-Pitch" and temp[i+1]=="Non-Pitch":
        shotplayed[i]=shot
    if temp[i]=="Non-Pitch" and temp[i+1]=="Pitch":
        shotplayed[i]=shot
        p=[]
print(shotplayed)
# Out:
# Counter({'Lofted Shot': 5, 'Pull Shot': 1})
# Counter({'Cut Shot': 6})
# Counter({'Cut Shot': 1})
# Counter({'Cut Shot': 2})
# ...

# %%
from datetime import datetime
start_time = datetime.now()
# do your work here


         
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16
reader = easyocr.Reader(['en'])
import numpy as np
import cv2
import os
count=0
img_array=[]
path="C://Users//Lohith//Downloads//RcbVsSrh2 - HD 720p.mp4"
cap = cv2.VideoCapture(path)
f = open("commentary.txt", "w")
g = open("comm_details.txt", "w")
g.write("Video Path : "+path+"\n")
g.write("\n")
g.write("Pitch and Non-Pitch Classified for each frame"+"\n")
g.write("["+",".join(temp)+"]"+"\n")
g.write("\n")

g.write("Shot classification for each fram"+"\n")
g.write("["+",".join(shotplayed)+"]"+"\n")

frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
# define codec and create VideoWriter object
#out = cv2.VideoWriter('/content/sample_data/output3.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 30, (frame_width,frame_height))
battingteam=""
noofovers=""
score=""
bowler=""
strike=""
nonstrike=""
prev={}
s1=""
n1=""
while(cap.isOpened()):
    ret, image = cap.read()
    try:
        output = reader.readtext(image)
    except:
        break
    if ret:
        #print(output)
        teams=["RCB","SRH","CSK","MI","DD","KKR","RR","KXIP"]
# Displaying the image
        resulttxt=[]
        for i in output:
            resulttxt.append(i[1])
        print(resulttxt)
        flag=0  
        for i in range(len(resulttxt)):
            if resulttxt[i] in teams:
                battingteam=resulttxt[i]
                try:
                    strike=resulttxt[i+1]
                except:
                    strike=""
            if resulttxt[i].startswith("OVERS"):
                flag=1
                noofovers=resulttxt[i]
                try:
                    nonstrike=resulttxt[i+1]
                except:
                    nonstrike=""
            if "-" in list(resulttxt[i]):
                score=resulttxt[i]
            if resulttxt[i]=="TIMELINE" or resulttxt[i]=="PROJECTED" or resulttxt[i].startswith("P"):
                try:
                    bowler=resulttxt[i+1]
                except:
                    bowler=""
        if "*" in list(nonstrike):
            strike,nonstrike=nonstrike,strike
            s1=strike
            n1=nonstrike
        p=""
        q=""
        for x in strike:
            if x.isalpha() or x==" ":
                p+=x
            else:
                break
        for x in nonstrike:
            if x.isalpha() or x==" ":
                q+=x
            else:
                break
        
        strike=p
        nonstrike=q
        

        if temp[count]=='Non-Pitch' and shotplayed[count]!='None' :
            #shot="Its a Wonderful "+shotplayed[count]
            shot=shotplayed[count]
        else:
            shot=""
        
        
        

        if len(shot)!=0:
            #f.write("type of shot played : "+shot+"\n")
        #f.write("\n")
        font = cv2.FONT_HERSHEY_SIMPLEX
        org = (500, 750)
        fontScale = 2
        color = (240,240,240)
        thickness = 5     
        if len(output)>=13 and len(output)<19 and flag==1:
            d={"Batting Team "+battingteam:(50,400),noofovers:(50,475),"Score "+score:(50,550),bowler+" bowling to "+strike:(500,800),nonstrike+" in the other end ":(500,900),shot:(800,80)}
            prev=d
# Using cv2.putText() method
            for i in d:
                if len(d[i])!=0:
                    image = cv2.putText(image,i, d[i], font,fontScale, color, thickness, cv2.LINE_AA)
        else:
            for i in prev:
                if len(prev[i])!=0:
                    image = cv2.putText(image,i, prev[i], font,fontScale, color, thickness, cv2.LINE_AA)
        print(strike)
        print(nonstrike)
        print(battingteam)
        print(noofovers)
        print(score)
        print(bowler)
        print(count)
        print(shot)
        print(temp[count])
                    
        #f.write("Frame "+str(count)+"\n")
        #f.write("View : "+temp[count]+"\n")
        #f.write("strike : "+strike+"\n")
        #f.write("nonstrike : "+nonstrike+"\n")
        #f.write("battingteam : "+battingteam+"\n")
        #f.write("noofovers : "+noofovers+"\n")
        #f.write("bowler : "+bowler+"\n")
    '''cv2.imwrite(os.path.join("/content/sample_data/image4" , str(c)+' frame.jpg'), image[0:925, 0:1812])
    c+=1
    out.write(image[0:925, 0:1812])
    output = reader.readtext(frame)
    font = cv2.FONT_HERSHEY_SIMPLEX
    #org = (500, 750)
    fontScale = 2
    color = (240,240,240)
    thickness = 5'''
    img_array.append(image[0:925, 0:1812])
    #cv2.imshow("frame",image[0:925, 0:1812])
    cv2.imwrite("frame%d.jpg" % count, image[0:925, 0:1812])
    count+=1
    if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    
cap.release()


'''out = cv2.VideoWriter("C:/Users/Lohith/Desktop/Captsone Review 2/Sample_Trim6.mp4",cv2.VideoWriter_fourcc(*'DIVX'), 15, (1280,720))

for i in range(len(img_array)):
    out.write(img_array[i])
out.release()'''
if s1!=strike:
    f.write(s1+",")
    f.write(n1+",")
else:
    f.write(strike+",")
    f.write(nonstrike+",")
f.write(bowler+",")
f.write(shot+",")

end_time = datetime.now()
        
f.write("\n")
print('Duration: {}'.format(end_time - start_time))
f.write('Duration: {}'.format(end_time - start_time))
g.write('Duration: {}'.format(end_time - start_time))
g.close()
f.close()
# Out:
# ['Fwhhibces', '81', 'RCB', 'V', 'SRH', 'WARNER', '28 20', 'TIMELINE', 'H PATEL', '0*20', '79-1', 'OVERS 6,3 (11)', 'HENRIQUES"', '36 14', 'NBT 7 0 2 7 NBA 6 7 | 4 4 2 WD']
# WARNER
# HENRIQUES
# SRH
# OVERS 6,3 (11)
# 79-1
# H PATEL
# 0
#
# Pitch
# ['awhaibcas', '81', 'RCB', 'V', 'SRH', 'WARNER', '28 20', 'TIMELINE', 'H PATEL', '0*20', '79-1', 'OVERS 6,3 (11)', 'HENRIQUES"', '36 14', 'NBT 7 0 2 7 NBA 6 7 | 4 4 2 WD']
# WARNER
# HENRIQUES
# SRH
# OVERS 6,3 (11)
# 79-1
# H PATEL
# 1
#
# Pitch
# ['awhhibcas', 'RCB', 'V', 'SRH', 'WARNER', '28 20', 'TIMELINE', 'H PATEL', '0*20', '79-1', 'OVERS 6,3 (11)', 'HENRIQUES "[36 14', 'NBT 7 0 2 7 NBA 6 7 | 4 4 2 WD']
# WARNER
# HENRIQUES
# SRH
# OVERS 6,3 (11)
# 79-1
# H PATEL
# 2
#
# Pitch
# ['awhhibcas', 'RCB', 'V', 'SRH', 'WARNER', '28 20', 'TIMELINE', 'H PATEL', '0*20', '79-1', 'OVERS 6,3 (11)', 'HENRIQUES', '36 14', 'NBT 7 0 2 7 NBA 6 7 | 4 4 2 WD']
# WARNER
# HENRIQUES
# SRH
# OVERS 6,3 (11)
# 79-1
# H PATEL
# 3
#
# Pitch
# ...

# %%
temp="Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch,Non-Pitch"
temp=temp.split(",")
print(len(temp))
shotplayed="None,None,None,None,None,None,None,None,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,None,None,None,None,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,Lofted Shot,None"
shotplayed=shotplayed.split(",")
print(len(shotplayed))
# Out:
# 164
# 164

# %%
print(shotplayed)
# Out:
# ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'N
# ...

# %%
cd Capstone Review 3
# Out:
# C:\Users\Lohith\Capstone Review 3

# %%
cd Vid4
# Out:
# C:\Users\Lohith\Capstone Review 3\Vid4

# %%
temp=['Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Non-Pitch', 'Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Pitch', 'Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch']
shotplayed=['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Pull Shot', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'None']

# %%
print(len(temp))
print(len(shotplayed))
cd Capstone Review 3
# Out:
#   Input In [5]
#     cd Capstone Review 3
#        ^
# SyntaxError: invalid syntax

# %%
path="C://Users//Lohith//Downloads//Made-with-Clipchamp-1.mp4"
g = open("comm_details.txt", "w")
g.write("Video Path : "+path+"\n")
g.write("\n")
g.write("Pitch and Non-Pitch Classified for each frame"+"\n")
g.write("["+",".join(temp)+"]"+"\n")
g.write("\n")
g.write("Shot classification for each fram"+"\n")
g.write("["+",".join(shotplayed)+"]"+"\n")
g.close()

# %%
cd Capstone Review 3
# Out:
# C:\Users\Lohith\Capstone Review 3

# %%
cd Vid5
# Out:
# C:\Users\Lohith\Capstone Review 3\Vid5
