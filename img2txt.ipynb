# %%
# !pip install easyocr
# Out:
# ...
#   Using cached easyocr-1.6.2-py3-none-any.whl (2.9 MB)
# ...
#      -------------------------------------- 293.9/293.9 kB 6.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 94.6/94.6 kB 5.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 35.0/35.0 MB 9.9 MB/s eta 0:00:00
# ...
#   Using cached python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# ...
#      ---------------------------------------- 1.3/1.3 MB 11.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.6.0.66
#     Uninstalling opencv-python-headless-4.6.0.66:
#       Successfully uninstalled opencv-python-headless-4.6.0.66
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16
reader = easyocr.Reader(['en'])
import pickle
with open('cric_shots.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
shotplayed=['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Pull Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Pull Shot', 'Lofted Shot', 'Pull Shot', 'Pull Shot', 'Pull Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'None']
print(shotplayed[30])
temp=['Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch', 'Non-Pitch']
len(temp)
# Out:
# Lofted Shot
# 100

# %%
from datetime import datetime
start_time = datetime.now()
# do your work here


         
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16
reader = easyocr.Reader(['en'])
import numpy as np
import cv2
import os
count=0
img_array=[]
path="C:/Users/Lohith/Downloads/RcbVsSrh - HD 720p.mp4"
cap = cv2.VideoCapture(path)
f = open("commentary.txt", "w")
g = open("comm_details.txt", "w")
g.write("Video Path : "+path+"\n")
g.write("\n")
g.write("Pitch and Non-Pitch Classified for each frame"+"\n")
g.write("["+",".join(temp)+"]"+"\n")
g.write("\n")

g.write("Shot classification for each fram"+"\n")
g.write("["+",".join(shotplayed)+"]"+"\n")

frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
# define codec and create VideoWriter object
#out = cv2.VideoWriter('/content/sample_data/output3.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 30, (frame_width,frame_height))
battingteam=""
noofovers=""
score=""
bowler=""
strike=""
nonstrike=""
prev={}
while(cap.isOpened()):
    ret, image = cap.read()
    try:
        output = reader.readtext(image)
    except:
        break
    if ret:
        #print(output)
        teams=["RCB","SRH","CSK","MI","DD","KKR","RR","KXIP"]
# Displaying the image
        resulttxt=[]
        for i in output:
            resulttxt.append(i[1])
        print(resulttxt)
        flag=0  
        for i in range(len(resulttxt)):
            if resulttxt[i] in teams:
                battingteam=resulttxt[i]
                try:
                    strike=resulttxt[i+1]
                except:
                    strike=""
            if resulttxt[i].startswith("OVERS"):
                flag=1
                noofovers=resulttxt[i]
                try:
                    nonstrike=resulttxt[i+1]
                except:
                    nonstrike=""
            if "-" in list(resulttxt[i]):
                score=resulttxt[i]
            if resulttxt[i]=="TIMELINE" or resulttxt[i]=="PROJECTED" or resulttxt[i].startswith("P"):
                try:
                    bowler=resulttxt[i+1]
                except:
                    bowler=""
        if "*" in list(nonstrike):
            strike,nonstrike=nonstrike,strike
        p=""
        q=""
        for x in strike:
            if x.isalpha():
                p+=x
            else:
                break
        for x in nonstrike:
            if x.isalpha():
                q+=x
            else:
                break
        
        strike=p
        nonstrike=q
        

        if temp[count]=='Non-Pitch' and shotplayed[count]!='None' :
            shot="Its a Wonderful "+shotplayed[count]
        else:
            shot=""
        
        
        

        if len(shot)!=0:
            f.write("type of shot played : "+shot+"\n")
        f.write("\n")
        font = cv2.FONT_HERSHEY_SIMPLEX
        org = (500, 750)
        fontScale = 2
        color = (240,240,240)
        thickness = 5     
        if len(output)>=13 and len(output)<19 and flag==1:
            d={"Batting Team "+battingteam:(50,400),noofovers:(50,475),"Score "+score:(50,550),bowler+" bowling to "+strike:(500,800),nonstrike+" in the other end ":(500,900),shot:(800,80)}
            prev=d
# Using cv2.putText() method
            for i in d:
                if len(d[i])!=0:
                    image = cv2.putText(image,i, d[i], font,fontScale, color, thickness, cv2.LINE_AA)
        else:
            for i in prev:
                if len(prev[i])!=0:
                    image = cv2.putText(image,i, prev[i], font,fontScale, color, thickness, cv2.LINE_AA)
        print(strike)
        print(nonstrike)
        print(battingteam)
        print(noofovers)
        print(score)
        print(bowler)
        print(count)
        print(shot)
        print(temp[count])
                    
        f.write("Frame "+str(count)+"\n")
        f.write("View : "+temp[count]+"\n")
        f.write("strike : "+strike+"\n")
        f.write("nonstrike : "+nonstrike+"\n")
        f.write("battingteam : "+battingteam+"\n")
        f.write("noofovers : "+noofovers+"\n")
        f.write("bowler : "+bowler+"\n")
    '''cv2.imwrite(os.path.join("/content/sample_data/image4" , str(c)+' frame.jpg'), image[0:925, 0:1812])
    c+=1
    out.write(image[0:925, 0:1812])
    output = reader.readtext(frame)
    font = cv2.FONT_HERSHEY_SIMPLEX
    #org = (500, 750)
    fontScale = 2
    color = (240,240,240)
    thickness = 5'''
    img_array.append(image[0:925, 0:1812])
    #cv2.imshow("frame",image[0:925, 0:1812])
    cv2.imwrite("frame%d.jpg" % count, image[0:925, 0:1812])
    count+=1
    if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    
cap.release()


'''out = cv2.VideoWriter("C:/Users/Lohith/Desktop/Captsone Review 2/Sample_Trim6.mp4",cv2.VideoWriter_fourcc(*'DIVX'), 15, (1280,720))

for i in range(len(img_array)):
    out.write(img_array[i])
out.release()'''

end_time = datetime.now()
f.write("\n")
print('Duration: {}'.format(end_time - start_time))
f.write('Duration: {}'.format(end_time - start_time))
g.write('Duration: {}'.format(end_time - start_time))
g.close()
f.close()
# Out:
# ['~aluhevbcas', 'RCB', 'V', 'SRH', 'WARNER', '36 24', 'PROECTED', 'CHAHAL', '0-17', '100-1', 'OVERS 8 (11)', 'HENRIQUES', '49 19', '12.50 = 138', '10 = 130', '12 = 136']
# WARNER
# HENRIQUES
# SRH
# OVERS 8 (11)
# 100-1
# CHAHAL
# 0
#
# Pitch
# ['~aluhevbcas', 'RCB', 'V', 'SRH', 'WARNER', '36 24', 'PROECTED', 'CHAHAL', '0-17', '100-1', 'OVERS 8 (11)', 'HENRIQUES', '49 19', '12.50 = 138', '10 = 130', '12 = 136']
# WARNER
# HENRIQUES
# SRH
# OVERS 8 (11)
# 100-1
# CHAHAL
# 1
#
# Pitch
# ['~aluhevbcas', 'RCB', 'V', 'SRH', 'WARNER', '36 24', 'PROECTED', 'CHAHAL', '0-17', '100-1', 'OVERS 8 (11)', 'HENRIQUES', '49 19', '12.50 = 138', '10 = 130', '12 = 136']
# WARNER
# HENRIQUES
# SRH
# OVERS 8 (11)
# 100-1
# CHAHAL
# 2
#
# Pitch
# ['~aluhevbcas', 'RCB', 'V', 'SRH', 'WARNER', '36 24', 'PROECTED', 'CHAHAL', '0-17', '100-1', 'OVERS 8 (11)', 'HENRIQUES', '49 19', '12.50 = 138', '10 = 130', '12 = 136']
# WARNER
# HENRIQUES
# SRH
# OVERS 8 (11)
# 100-1
# CHAHAL
# 3
#
# Pitch
# ...

# %%
print(shotplayed[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 print(shotplayed[1])
#
# IndexError: string index out of range

# %%
out = cv2.VideoWriter("C:/Users/Lohith/Desktop/Captsone Review 2/Sample_Trim8.mp4",cv2.VideoWriter_fourcc(*'DIVX'), 15, (720,480))

for i in range(len(img_array)):
    out.write(img_array[i])
out.release()

# %%
import cv2
import numpy as np
arr=[]
cap = cv2.VideoCapture("C:/Users/Lohith/Desktop/Captsone Review 2/RcbVsSrh - HD 720p.mp4")
while True:
    ret, frame = cap.read()
    if ret == True:
        arr.append(frame)
        
    else:
        break
    
cap.release()
cv2.destroyAllWindows()
print(arr)
out = cv2.VideoWriter("C:/Users/Lohith/Desktop/Captsone Review 2/Sample_Trim6.mp4",cv2.VideoWriter_fourcc(*'DIVX'), 30, (1920,1080))
for i in range(len(arr)):
    out.write(arr[i])
out.release()
# Out:
# [array([[[ 53, 120,  89],
#         [ 64, 131, 100],
#         [ 63, 130,  99],
#         ...,
#         [ 64, 113,  89],
#         [  4,  48,  25],
#         [  0,  16,   0]],
#
#        [[ 53, 120,  89],
#         [ 64, 131, 100],
#         [ 63, 130,  99],
#         ...,
#         [ 64, 113,  89],
#         [  4,  48,  25],
#         [  0,  16,   0]],
#
#        [[ 53, 120,  89],
#         [ 64, 131, 100],
#         [ 63, 130,  99],
#         ...,
#         [ 64, 113,  89],
#         [  4,  48,  25],
#         [  0,  15,   0]],
#
#        ...,
#
#        [[ 43, 110,  79],
#         [ 59, 126,  95],
#         [ 58, 125,  94],
#         ...,
#         [ 69, 137, 110],
#         [ 24,  51,  31],
#         [  0,   8,   0]],
#
#        [[ 43, 110,  79],
#         [ 59, 126,  95],
#         [ 58, 125,  94],
#         ...,
#         [ 69, 137, 110],
#         [ 24,  51,  31],
#         [  0,   8,   0]],
#
#        [[ 43, 110,  79],
#         [ 59, 126,  95],
#         [ 58, 125,  94],
# ...

# %%
cd Vid2
# Out:
# C:\Users\Lohith\Vid2

# %%
# importing libraries
import os
import cv2
from PIL import Image

# Checking the current directory path
print(os.getcwd())

# Folder which contains all the images
# from which video is to be generated
os.chdir("C:\\Users\\Lohith\\Frame")
path = "C:\\Users\\Lohith\\Frame"

mean_height = 0
mean_width = 0

num_of_images = len(os.listdir('.'))
# print(num_of_images)

for file in os.listdir('.'):
	im = Image.open(os.path.join(path, file))
	width, height = im.size
	mean_width += width
	mean_height += height
	# im.show() # uncomment this for displaying the image

# Finding the mean height and width of all images.
# This is required because the video frame needs
# to be set with same width and height. Otherwise
# images not equal to that width height will not get
# embedded into the video
mean_width = int(mean_width / num_of_images)
mean_height = int(mean_height / num_of_images)

# print(mean_height)
# print(mean_width)

# Resizing of the images to give
# them same width and height
for file in os.listdir('.'):
	if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith("png"):
		# opening image using PIL Image
		im = Image.open(os.path.join(path, file))

		# im.size includes the height and width of image
		width, height = im.size
		print(width, height)

		# resizing
		imResize = im.resize((mean_width, mean_height), Image.ANTIALIAS)
		imResize.save( file, 'JPEG', quality = 95) # setting quality
		# printing each resized image name
		print(im.filename.split('\\')[-1], " is resized")


# Video Generating function
def generate_video():
	image_folder = '.' # make sure to use your folder
	video_name = 'samp.mp4'
	os.chdir("C:\\Users\\Lohith\\Frame")
	
	images = [img for img in os.listdir(image_folder)
			if img.endswith(".jpg") or
				img.endswith(".jpeg") or
				img.endswith("png")]
	
	# Array images should only consider
	# the image files ignoring others if any
	print(images)

	frame = cv2.imread(os.path.join(image_folder, images[0]))

	# setting the frame width, height width
	# the width, height of first image
	height, width, layers = frame.shape

	video = cv2.VideoWriter(video_name, 0, 1, (width, height))

	# Appending the images to the video one by one
	for image in images:
		video.write(cv2.imread(os.path.join(image_folder, image)))
	
	# Deallocating memories taken for window creation
	cv2.destroyAllWindows()
	video.release() # releasing the video generated


# Calling the generate_video function
generate_video()
# Out:
# C:\Users\Lohith\frame
# 1812 925
# frame0.jpg  is resized
# 1812 925
# frame1.jpg  is resized
# 1812 925
# frame10.jpg  is resized
# 1812 925
# C:\Users\Lohith\AppData\Local\Temp\ipykernel_9280\221058087.py:50: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   imResize = im.resize((mean_width, mean_height), Image.ANTIALIAS)
# frame100.jpg  is resized
# 1812 925
# frame101.jpg  is resized
# 1812 925
# frame102.jpg  is resized
# 1812 925
# frame103.jpg  is resized
# 1812 925
# frame104.jpg  is resized
# 1812 925
# frame105.jpg  is resized
# 1812 925
# frame106.jpg  is resized
# 1812 925
# frame107.jpg  is resized
# 1812 925
# frame108.jpg  is resized
# 1812 925
# frame109.jpg  is resized
# 1812 925
# frame11.jpg  is resized
# 1812 925
# frame110.jpg  is resized
# 1812 925
# frame111.jpg  is resized
# 1812 925
# frame112.jpg  is resized
# 1812 925
# frame113.jpg  is resized
# 1812 925
# ...

# %%
cd Frame
# Out:
# C:\Users\Lohith\Frame
